# %%
import pandas as pd
import numpy as np 
import datetime
from numpy import array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load data + set time
data = pd.read_csv('Volume_Data.csv')

# convert the data type of the column to DateTime
data['Date']= pd.to_datetime(data['Date']) 
print(data.dtypes)
data['Date'] = pd.to_datetime(data.Date, format='%Y-%m-%d')
data.index = data['Date']

plt.figure(figsize=(16, 8))
plt.title('Luzon Load')
plt.plot(data['Value'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Load', fontsize=18)
plt.show()

data
# Out:
# Date      datetime64[ns]
# Period             int64
# Value            float64
# dtype: object
#                                    Date  Period   Value
# Date
# 2020-05-02 00:00:00 2020-05-02 00:00:00       1  7466.0
# 2020-05-02 01:00:00 2020-05-02 01:00:00       2  7238.1
# 2020-05-02 02:00:00 2020-05-02 02:00:00       3  6934.5
# 2020-05-02 03:00:00 2020-05-02 03:00:00       4  6706.9
# 2020-05-02 04:00:00 2020-05-02 04:00:00       5  6555.9
# ...                                 ...     ...     ...
# 2020-08-02 13:00:00 2020-08-02 13:00:00      14  7340.2
# 2020-08-02 14:00:00 2020-08-02 14:00:00      15  7115.1
# 2020-08-02 15:00:00 2020-08-02 15:00:00      16  7032.0
# 2020-08-02 16:00:00 2020-08-02 16:00:00      17  6814.4
# 2020-08-02 17:00:00 2020-08-02 17:00:00      18  6938.8
#
# [2226 rows x 3 columns]

# %% [raw]
# # show data for seprated periods
# name = "data_split"
# plotnames=[]
# plotlist=[]
#
# for j in range(1,25,6):
#     data_split_name = name[:11] + str(j)
#     data_split_name = data.loc[data['Period'] == j]
#     plotlist.append(data_split_name)
#     plotnames.append(str(j))
#
#
# plt.figure(figsize=(40,20))
# plt.title('Louzan Load on diff Priod')
# for i in plotlist:
#     plt.plot(i['Value'])
# plt.xlabel('Date', fontsize=18)
# plt.ylabel('Load', fontsize=18)
# plt.legend(plotnames, loc='upper right')
# plt.show()

# %%
# extract data for each period + specific date
data_split = data#.loc[data['Period'] == 18]
# define input sequence
data_seq_train = data_split.loc[data_split["Date"] <= "2020-07-27"]
data_seq_test = data_split.loc[data_split["Date"] > "2020-07-27"]
data_seq_test
# Out:
#                                    Date  Period   Value
# Date
# 2020-07-27 01:00:00 2020-07-27 01:00:00       2  7380.3
# 2020-07-27 02:00:00 2020-07-27 02:00:00       3  7159.0
# 2020-07-27 03:00:00 2020-07-27 03:00:00       4  6995.6
# 2020-07-27 04:00:00 2020-07-27 04:00:00       5  6887.5
# 2020-07-27 05:00:00 2020-07-27 05:00:00       6  6863.7
# ...                                 ...     ...     ...
# 2020-08-02 13:00:00 2020-08-02 13:00:00      14  7340.2
# 2020-08-02 14:00:00 2020-08-02 14:00:00      15  7115.1
# 2020-08-02 15:00:00 2020-08-02 15:00:00      16  7032.0
# 2020-08-02 16:00:00 2020-08-02 16:00:00      17  6814.4
# 2020-08-02 17:00:00 2020-08-02 17:00:00      18  6938.8
#
# [161 rows x 3 columns]

# %%
# define input sequence
data_seq_train = list(data_seq_train['Value'])
data_seq_test = list(data_seq_test['Value'])

data_seq_train
# Out:
# [7466.0,
#  7238.1,
#  6934.5,
#  6706.9,
#  6555.9,
#  6315.5,
#  6004.0,
#  6188.9,
#  6540.6,
#  6905.9,
#  7133.6,
#  7108.4,
#  7303.1,
#  7552.4,
#  7584.8,
#  7369.7,
#  6946.6,
#  6912.1,
#  7608.4,
#  7682.5,
#  7945.9,
#  7983.4,
#  7870.2,
#  7753.2,
#  7524.2,
#  7242.0,
#  6969.1,
#  6735.9,
#  6520.9,
#  6263.6,
#  6158.9,
#  6360.0,
#  6624.3,
#  6866.2,
#  7113.5,
#  7123.9,
#  7112.0,
#  7227.2,
#  7214.7,
#  6981.4,
#  6741.7,
#  6908.0,
#  7540.9,
#  7682.2,
#  8017.9,
#  8043.3,
#  7774.9,
#  7587.1,
#  7242.2,
#  6897.4,
#  6664.1,
#  6470.3,
#  6363.4,
#  6265.8,
#  6094.8,
#  6674.0,
#  7328.2,
#  7728.3,
#  8007.7,
#  7902.8,
#  8262.6,
#  8547.3,
#  8550.9,
#  8319.5,
#  7922.6,
#  7661.7,
#  8117.4,
#  8278.3,
#  8489.6,
#  8601.4,
#  8504.6,
#  8360.5,
#  8200.5,
#  7936.1,
#  7621.5,
#  7382.4,
#  7214.3,
#  7056.8,
#  6726.2,
#  6915.5,
#  7528.7,
#  7910.9,
#  8212.9,
#  8172.9,
#  8345.7,
#  8591.7,
#  8700.8,
#  8353.1,
#  7790.2,
#  7507.5,
#  8162.6,
#  8364.7,
#  8758.6,
#  8776.5,
#  8675.8,
#  8522.9,
#  8361.5,
#  8074.2,
#  7835.4,
#  7606.6,
#  7416.5,
#  7124.0,
#  6744.1,
#  7273.2,
#  7856.2,
#  8102.7,
#  8365.0,
#  8434.5,
#  8691.2,
#  9017.9,
#  9064.0,
#  8705.1,
#  8102.2,
#  7911.7,
#  8450.3,
#  8618.1,
#  8931.7,
#  8981.4,
#  8864.3,
#  8549.9,
#  8393.3,
#  8124.0,
#  7881.8,
#  7649.9,
#  7593.9,
#  7300.5,
#  7016.0,
#  7349.2,
#  7784.2,
#  8130.9,
#  8472.3,
#  8483.0,
#  8810.0,
#  9160.8,
#  9116.9,
#  8745.2,
#  8100.8,
#  7767.8,
#  8453.4,
#  8605.5,
#  8995.0,
#  8926.5,
#  8769.0,
#  8814.6,
#  8638.8,
#  8362.1,
#  8063.2,
#  7813.9,
#  7652.1,
#  7247.1,
#  7036.1,
#  7390.0,
#  7793.2,
#  8184.1,
#  8482.6,
#  8485.5,
#  8753.1,
#  9116.0,
#  9115.6,
#  8738.8,
#  8026.5,
#  7732.5,
#  8407.3,
#  8691.5,
#  8992.5,
#  8914.2,
#  8865.7,
#  8667.1,
#  8404.3,
#  8161.0,
#  7867.7,
#  7625.1,
#  7457.1,
#  7138.7,
#  6971.8,
#  7094.8,
#  7483.5,
#  7760.1,
#  8001.3,
#  8003.9,
#  8195.3,
#  8552.6,
#  8559.2,
#  8351.8,
#  7909.5,
#  7712.1,
#  7988.5,
#  8123.1,
#  8186.4,
#  8262.5,
#  8224.5,
#  7976.4,
#  7861.6,
#  7632.4,
#  7344.1,
#  7120.5,
#  6878.4,
#  6592.3,
#  6531.4,
#  6637.5,
#  6972.9,
#  7334.6,
#  7504.7,
#  7458.0,
#  7702.4,
#  7907.5,
#  8102.3,
#  7939.9,
#  7786.2,
#  7642.9,
#  8188.0,
#  8244.6,
#  8665.7,
#  8588.8,
#  8319.3,
#  8172.1,
#  7868.4,
#  7553.3,
#  7295.5,
#  7066.1,
#  6933.6,
#  6777.5,
#  6632.2,
#  7096.3,
#  7582.6,
#  8020.5,
#  8358.7,
#  8378.9,
#  8685.7,
#  9014.8,
#  9034.1,
#  8635.8,
#  7928.2,
#  7589.3,
#  8254.9,
#  8567.3,
#  8833.4,
#  8932.7,
#  8815.0,
#  8678.6,
#  8546.6,
#  8279.1,
#  7971.2,
#  7703.2,
#  7499.3,
#  7275.2,
#  6973.0,
#  7348.5,
#  7902.5,
#  8240.7,
#  8467.6,
#  8423.5,
#  8721.2,
#  9126.3,
#  9083.1,
#  8661.1,
#  8057.7,
#  7678.3,
#  8263.8,
#  8503.8,
#  8803.6,
#  8777.7,
#  8754.7,
#  8574.2,
#  8486.4,
#  8166.8,
#  7927.1,
#  7652.0,
#  7492.2,
#  7162.4,
#  6999.7,
#  7374.5,
#  7910.0,
#  8286.1,
#  8727.4,
#  8749.6,
#  8998.8,
#  9260.1,
#  9181.1,
#  8711.6,
#  8058.5,
#  7648.6,
#  8195.8,
#  8536.6,
#  8833.7,
#  8841.9,
#  8770.1,
#  8665.6,
#  8556.4,
#  8285.7,
#  7977.9,
#  7671.4,
#  7475.3,
#  7193.7,
#  7019.9,
#  7401.9,
#  7977.3,
#  8256.5,
#  8483.8,
#  8451.0,
#  8611.7,
#  8917.8,
#  8637.2,
#  8210.4,
#  7441.8,
#  7360.3,
#  8009.4,
#  8314.6,
#  8403.2,
#  8421.6,
#  8358.2,
#  8268.4,
#  7943.9,
#  7655.8,
#  7393.8,
#  7157.5,
#  6956.6,
#  6716.0,
#  6696.5,
#  7134.3,
#  7320.4,
#  7567.5,
#  7371.2,
#  7545.2,
#  7488.6,
#  7397.7,
#  7256.0,
#  6832.9,
#  6533.4,
#  6142.8,
#  6567.8,
#  6242.4,
#  5859.3,
#  5647.1,
#  5857.7,
#  5659.0,
#  5531.9,
#  5489.9,
#  5455.1,
#  5276.4,
#  5182.5,
#  5186.3,
#  5168.5,
#  5566.5,
#  6215.7,
#  6648.3,
#  7032.3,
#  7070.1,
#  7370.4,
#  7387.8,
#  7281.8,
#  7033.9,
#  6710.9,
#  6670.7,
#  7335.9,
#  7417.6,
#  7642.1,
#  7479.5,
#  7440.3,
#  7274.1,
#  7014.1,
#  6765.1,
#  6498.3,
#  6283.3,
#  6130.6,
#  5964.1,
#  5923.4,
#  6170.0,
#  6871.6,
#  7188.1,
#  7277.8,
#  7433.7,
#  7499.9,
#  7731.7,
#  7750.9,
#  7643.1,
#  7331.2,
#  7316.8,
#  7980.7,
#  8178.5,
#  8418.1,
#  8495.1,
#  8485.4,
#  8153.1,
#  7775.1,
#  7609.0,
#  7297.2,
#  7063.7,
#  6909.8,
#  6822.6,
#  6636.0,
#  7256.9,
#  8025.7,
#  8490.2,
#  8879.5,
#  8994.2,
#  9147.4,
#  9160.8,
#  8998.2,
#  8561.8,
#  8294.4,
#  7987.0,
#  8368.6,
#  8560.5,
#  8795.9,
#  8782.2,
#  8686.7,
#  8503.5,
#  8398.2,
#  8034.2,
#  7766.7,
#  7477.4,
#  7372.5,
#  7167.7,
#  6970.0,
#  7496.8,
#  8247.4,
#  8880.5,
#  9203.8,
#  9100.2,
#  8926.9,
#  8914.2,
#  8855.5,
#  8514.3,
#  7956.8,
#  7534.8,
#  8189.0,
#  8321.0,
#  8587.6,
#  8536.1,
#  8444.1,
#  8262.9,
#  8135.1,
#  7840.0,
#  7549.8,
#  7479.4,
#  7241.0,
#  7132.7,
#  7013.7,
#  7585.9,
#  8201.7,
#  8748.8,
#  9053.9,
#  8942.5,
#  9077.1,
#  9528.0,
#  9534.6,
#  9114.5,
#  8442.6,
#  7957.4,
#  8556.0,
#  8745.5,
#  8966.3,
#  8952.6,
#  8898.4,
#  8782.9,
#  8541.9,
#  8291.1,
#  8056.4,
#  7820.3,
#  7612.1,
#  7349.7,
#  7296.4,
#  7900.8,
#  8513.2,
#  8937.3,
#  9183.0,
#  9159.2,
#  9355.2,
#  9643.0,
#  9457.0,
#  9118.8,
#  8340.7,
#  7998.9,
#  8709.8,
#  8714.1,
#  9074.1,
#  9077.4,
#  9012.0,
#  8855.0,
#  8626.5,
#  8344.0,
#  8050.1,
#  7807.8,
#  7681.8,
#  7477.8,
#  7364.0,
#  7866.8,
#  8440.2,
#  8871.8,
#  9265.2,
#  9194.3,
#  9343.4,
#  9479.4,
#  9349.3,
#  8981.6,
#  8193.9,
#  7809.8,
#  8376.2,
#  8685.0,
#  8941.3,
#  8946.6,
#  8696.1,
#  8385.9,
#  8253.4,
#  8177.7,
#  8002.8,
#  7764.9,
#  7612.6,
#  7321.2,
#  7060.3,
#  7359.6,
#  7859.5,
#  8245.1,
#  8544.6,
#  8616.4,
#  8754.2,
#  9011.6,
#  8806.0,
#  8384.1,
#  7497.4,
#  7642.8,
#  8013.0,
#  7945.0,
#  8074.3,
#  7986.4,
#  7755.3,
#  7444.5,
#  7170.6,
#  7149.9,
#  7021.1,
#  6862.0,
#  6705.6,
#  6390.3,
#  6508.4,
#  6679.9,
#  7060.1,
#  7430.6,
#  7750.3,
#  7694.8,
#  7990.1,
#  8256.5,
#  8152.1,
#  7940.3,
#  7531.0,
#  7376.8,
#  7932.5,
#  8073.6,
#  8169.8,
#  8198.1,
#  8190.1,
#  7823.0,
#  7659.3,
#  7463.3,
#  7217.1,
#  7008.5,
#  6916.3,
#  6628.8,
#  6555.1,
#  6584.0,
#  7295.5,
#  7692.2,
#  8023.5,
#  8020.6,
#  8101.0,
#  8349.9,
#  8388.0,
#  8061.7,
#  7699.2,
#  7609.9,
#  8145.3,
#  8360.8,
#  8639.3,
#  8679.5,
#  8508.4,
#  8224.7,
#  8035.0,
#  7927.2,
#  7830.7,
#  7605.0,
#  7357.4,
#  7183.1,
#  7024.0,
#  7757.3,
#  8433.9,
#  8964.4,
#  9360.8,
#  9377.2,
#  9444.7,
#  9625.6,
#  9295.8,
#  8831.3,
#  8007.0,
#  7718.0,
#  8269.0,
#  8373.6,
#  8626.3,
#  8554.8,
#  8567.5,
#  8452.2,
#  8235.8,
#  7966.1,
#  7688.2,
#  7423.6,
#  7344.1,
#  7010.6,
#  7347.4,
#  7792.0,
#  8402.9,
#  8918.1,
#  9348.5,
#  9201.6,
#  9439.1,
#  9657.9,
#  9551.8,
#  9062.6,
#  8359.6,
#  8049.6,
#  8534.7,
#  8707.2,
#  8347.4,
#  8623.4,
#  8499.9,
#  8408.6,
#  8263.8,
#  8004.4,
#  7744.6,
#  7500.1,
#  7416.9,
#  7240.1,
#  7181.5,
#  7889.1,
#  8543.7,
#  9066.0,
#  9377.2,
#  9282.6,
#  9445.7,
#  9717.5,
#  9405.0,
#  8765.3,
#  8253.9,
#  7819.9,
#  8430.9,
#  8386.6,
#  8604.5,
#  8520.9,
#  8500.6,
#  8259.6,
#  8102.6,
#  7889.2,
#  7615.6,
#  7395.0,
#  7285.2,
#  7083.1,
#  7064.4,
#  7855.7,
#  8359.9,
#  8938.1,
#  9210.2,
#  9236.7,
#  9329.8,
#  9573.0,
#  9493.2,
#  9130.6,
#  8339.6,
#  7965.6,
#  8377.0,
#  8289.9,
#  8605.8,
#  8606.6,
#  8511.7,
#  8396.4,
#  8234.5,
#  8060.7,
#  7780.1,
#  7553.4,
#  7242.9,
#  6730.2,
#  6740.7,
#  7179.3,
#  7909.1,
#  8452.3,
#  8679.5,
#  8654.3,
#  8734.6,
#  9009.4,
#  9000.3,
#  8719.6,
#  8208.6,
#  8102.3,
#  8566.2,
#  8494.2,
#  8819.4,
#  8758.1,
#  8784.7,
#  8659.3,
#  8479.0,
#  8169.4,
#  7934.0,
#  7663.7,
#  7389.0,
#  7059.1,
#  6927.9,
#  7201.8,
#  7716.2,
#  7992.9,
#  8370.2,
#  8254.5,
#  8325.9,
#  8495.9,
#  8507.9,
#  8265.1,
#  7825.1,
#  7696.8,
#  8066.0,
#  8309.3,
#  8653.9,
#  8749.3,
#  8665.9,
#  8355.2,
#  8063.2,
#  7747.3,
#  7470.7,
#  7242.2,
#  7074.1,
#  6761.6,
#  7096.2,
#  7896.4,
#  8599.3,
#  9263.7,
#  9540.6,
#  9557.7,
#  9787.8,
#  10054.3,
#  10031.7,
#  9832.2,
#  9044.4,
#  8492.9,
#  8624.4,
#  8459.0,
#  8927.0,
#  9116.4,
#  9148.4,
#  9005.5,
#  8774.2,
#  8461.4,
#  8191.4,
#  7917.4,
#  7772.3,
#  7607.0,
#  7508.9,
#  8220.4,
#  9010.6,
#  9595.9,
#  9942.9,
#  9816.5,
#  9908.4,
#  10239.9,
#  10218.9,
#  9767.2,
#  8868.6,
#  8334.2,
#  8671.4,
#  8908.8,
#  9231.7,
#  9301.2,
#  9094.0,
#  8765.0,
#  8533.7,
#  8411.1,
#  8252.5,
#  8026.8,
#  7922.6,
#  7679.3,
#  7637.3,
#  8460.6,
#  9174.1,
#  9666.0,
#  9931.0,
#  9804.2,
#  9909.1,
#  10270.9,
#  10187.6,
#  9830.7,
#  8943.1,
#  8809.1,
#  8855.8,
#  9256.7,
#  9311.3,
#  9456.9,
#  9271.4,
#  8963.5,
#  8699.1,
#  8487.1,
#  8370.9,
#  8086.3,
#  7957.3,
#  7706.6,
#  7877.9,
#  8664.5,
#  9292.4,
#  9615.6,
#  9821.2,
#  9760.5,
#  9930.0,
#  10294.7,
#  10194.4,
#  9838.7,
#  9322.5,
#  8447.5,
#  8953.7,
#  9058.3,
#  9467.4,
#  9579.9,
#  9295.8,
#  9019.5,
#  8778.7,
#  8674.9,
#  8540.1,
#  8299.5,
#  8143.3,
#  7918.8,
#  7898.0,
#  8601.6,
#  9174.1,
#  9471.7,
#  9813.3,
#  9760.2,
#  10014.2,
#  10445.8,
#  10218.9,
#  9863.6,
#  9056.7,
#  8422.2,
#  8887.7,
#  9199.8,
#  9559.1,
#  9697.0,
#  9477.1,
#  9022.0,
#  8951.3,
#  8875.1,
#  8690.7,
#  8434.9,
#  8200.4,
#  7828.2,
#  7665.9,
#  8146.9,
#  8555.1,
#  8932.6,
#  9179.8,
#  9126.4,
#  9286.9,
#  9627.2,
#  9621.0,
#  9279.8,
#  8755.8,
#  8192.9,
#  8852.5,
#  8905.7,
#  9274.5,
#  9309.8,
#  9435.2,
#  9154.4,
#  9159.9,
#  8814.3,
#  8530.8,
#  8248.8,
#  7931.6,
#  7466.6,
#  7499.2,
#  7806.5,
#  8173.5,
#  8475.7,
#  8813.9,
#  8771.4,
#  9047.6,
#  9387.6,
#  9336.0,
#  9085.8,
#  8765.2,
#  8473.9,
#  8710.6,
#  8949.4,
#  9154.9,
#  9349.4,
#  9104.1,
#  8824.1,
#  8494.8,
#  8205.3,
#  7964.4,
#  7777.5,
#  7620.9,
#  7419.2,
#  7626.8,
#  8350.5,
#  9140.9,
#  9614.4,
#  10010.2,
#  9768.0,
#  10020.5,
#  10362.0,
#  10309.2,
#  9948.9,
#  9218.9,
#  8588.2,
#  8927.6,
#  9152.4,
#  9449.3,
#  9509.0,
#  9397.4,
#  9207.8,
#  8982.6,
#  8722.6,
#  8425.5,
#  8105.8,
#  7955.3,
#  7728.2,
#  7699.2,
#  8439.5,
#  9097.1,
#  9590.4,
#  9901.4,
#  9912.4,
#  10093.1,
#  10410.8,
#  10402.2,
#  9981.4,
#  8941.2,
#  8276.9,
#  8722.4,
#  9054.0,
#  9331.8,
#  9390.6,
#  9347.4,
#  9147.4,
#  8965.1,
#  8649.4,
#  8351.9,
#  8120.1,
#  7988.7,
#  7705.6,
#  7710.0,
#  8420.5,
#  9158.6,
#  9649.6,
#  9892.2,
#  9729.5,
#  9882.5,
#  10054.9,
#  9679.1,
#  9051.3,
#  8470.3,
#  8236.2,
#  8730.7,
#  8677.8,
#  8703.2,
#  8956.2,
#  9025.1,
#  8811.9,
#  8656.3,
#  8422.1,
#  8074.6,
#  7829.4,
#  7599.1,
#  7451.0,
#  7473.5,
#  8031.8,
#  8500.0,
#  8956.3,
#  9129.6,
#  9157.9,
#  9276.8,
#  9642.6,
#  9566.6,
#  9237.9,
#  8489.8,
#  7965.9,
#  8485.7,
#  8466.4,
#  8508.6,
#  8410.5,
#  8221.3,
#  8145.6,
#  7993.7,
#  7624.4,
#  7492.1,
#  7313.0,
#  7138.4,
#  7044.2,
#  7019.1,
#  6970.4,
#  7208.8,
#  7686.0,
#  7872.2,
#  7823.3,
#  7864.7,
#  7812.2,
#  7640.5,
#  7485.9,
#  ...]

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
# choose a number of time steps
n_steps = 24
# split into samples
X_train, y_train = split_sequence(data_seq_train, n_steps)
X_test, y_test = split_sequence(data_seq_test, n_steps)

# reshape from [samples, timesteps] into [samples, timesteps, features]
n_features = 1
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))

print(X_train.shape[0], X_train.shape[1])
# y_test
# Out:
# 2041 24

# %%
# define model
model = Sequential()
model.add(LSTM(128, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
model.add(LSTM(64, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse', metrics=['mean_absolute_percentage_error'])
# fit model
model.fit(X_train, y_train, epochs=100, verbose=1, batch_size = 24)
# Out:
# Epoch 1/20
# 86/86 [==============================] - 2s 18ms/step - loss: 30091268.0000 - mean_absolute_percentage_error: 50.1057
# Epoch 2/20
# 86/86 [==============================] - 2s 18ms/step - loss: 10279448.0000 - mean_absolute_percentage_error: 29.9644
# Epoch 3/20
# 86/86 [==============================] - 2s 18ms/step - loss: 16919352.0000 - mean_absolute_percentage_error: 35.0676
# Epoch 4/20
# 86/86 [==============================] - 2s 18ms/step - loss: 8171974.5000 - mean_absolute_percentage_error: 23.0556
# Epoch 5/20
# 86/86 [==============================] - 2s 20ms/step - loss: 14140012.0000 - mean_absolute_percentage_error: 34.0594
# Epoch 6/20
# 86/86 [==============================] - 2s 21ms/step - loss: 1370542.5000 - mean_absolute_percentage_error: 10.4955
# Epoch 7/20
# 86/86 [==============================] - 2s 19ms/step - loss: 817634.0625 - mean_absolute_percentage_error: 8.2091
# Epoch 8/20
# 86/86 [==============================] - 2s 18ms/step - loss: 3135008.7500 - mean_absolute_percentage_error: 15.1223
# Epoch 9/20
# 86/86 [==============================] - 2s 24ms/step - loss: 2675791.0000 - mean_absolute_percentage_error: 14.2574
# Epoch 10/20
# 86/86 [==============================] - 2s 19ms/step - loss: 764753.3125 - mean_absolute_percentage_error: 8.0677
# Epoch 11/20
# 86/86 [==============================] - 2s 19ms/step - loss: 563384.7500 - mean_absolute_percentage_error: 7.1728: 1s - loss: 596299.8125 - mean_absolute_
# Epoch 12/20
# 86/86 [==============================] - 2s 19ms/step - loss: 566868.6875 - mean_absolute_percentage_error: 7.2101: 1s - loss: 630826.7500 - mean_absolute_
# Epoch 13/20
# 86/86 [==============================] - 2s 18ms/step - loss: 549433.6875 - mean_absolute_percentage_error: 7.1142
# Epoch 14/20
# 86/86 [==============================] - 1s 17ms/step - loss: 468488.5625 - mean_absolute_percentage_error: 6.6056
# Epoch 15/20
# 86/86 [==============================] - 2s 18ms/step - loss: 421181.6562 - mean_absolute_percentage_error: 6.0694
# Epoch 16/20
# 86/86 [==============================] - 1s 17ms/step - loss: 2470903.7500 - mean_absolute_percentage_error: 12.2395
# Epoch 17/20
# 86/86 [==============================] - 2s 18ms/step - loss: 5180374.5000 - mean_absolute_percentage_error: 18.4430
# Epoch 18/20
# 86/86 [==============================] - 2s 19ms/step - loss: 1023813.5000 - mean_absolute_percentage_error: 10.0250
# Epoch 19/20
# 86/86 [==============================] - 2s 18ms/step - loss: 716808.0000 - mean_absolute_percentage_error: 8.4269
# Epoch 20/20
# 86/86 [==============================] - 1s 17ms/step - loss: 633865.3750 - mean_absolute_percentage_error: 7.7843

# %%
# demonstrate prediction
y_test_hat = model.predict(X_test, verbose=0)
y_test = list(y_test)
for i in range(len(y_test_hat)):
    print(y_test_hat[i]-y_test[i])
# Out:
# [-119.54883]
# [69.407715]
# [525.56836]
# [840.2793]
# [1253.7437]
# [1490.1055]
# [1184.2383]
# [417.48438]
# [139.73438]
# [8.549805]
# [172.14941]
# [-305.12305]
# [-836.95215]
# [-740.6592]
# [-752.60645]
# [30.789062]
# [261.667]
# [-269.77246]
# [-424.3506]
# [-437.08398]
# [-352.70508]
# [-313.73047]
# [-272.36133]
# [43.86621]
# [144.4502]
# [555.68994]
# [787.0415]
# [1061.9648]
# [1406.8823]
# [1636.4995]
# [1021.208]
# [618.46875]
# [401.12695]
# [-32.708984]
# [125.74121]
# [27.844727]
# [-373.59668]
# [-163.85254]
# [-371.4463]
# [325.52588]
# [551.3657]
# [-45.13965]
# [-35.365234]
# [-139.64551]
# [-40.42334]
# [44.356934]
# [-34.1875]
# [272.73486]
# [349.58252]
# [821.71924]
# [1051.9468]
# [1230.2134]
# [1461.6392]
# [1172.6655]
# [938.8496]
# [260.25488]
# [-122.84668]
# [-371.2627]
# [-537.4717]
# [-861.3506]
# [-1248.4375]
# [-1093.5166]
# [-917.79004]
# [-5.5820312]
# [-43.967285]
# [-243.86621]
# [-397.37842]
# [-371.1753]
# [-398.38477]
# [-152.0581]
# [-119.99219]
# [29.631836]
# [90.87109]
# [533.59766]
# [707.6323]
# [1034.7739]
# [1353.3877]
# [1532.5547]
# [1667.5547]
# [1399.9263]
# [1027.9072]
# [737.6338]
# [530.6929]
# [268.7539]
# [-52.257812]
# [-69.81543]
# [152.9331]
# [441.38232]
# [329.4419]
# [-309.4463]
# [-440.11768]
# [-323.04932]
# [-294.12793]
# [-324.74854]
# [-141.15967]
# [72.80762]
# [179.6128]
# [347.00635]
# [532.06934]
# [920.70605]
# [1074.104]
# [1063.646]
# [809.1763]
# [343.23438]
# [-65.77881]
# [-326.26758]
# [-428.01904]
# [-563.5508]
# [-541.7339]
# [-213.44385]
# [114.73096]
# [561.81445]
# [456.46387]
# [54.634766]
# [-164.31348]
# [-203.36621]
# [-145.3667]
# [-140.89648]
# [-45.121094]
# [186.1294]
# [247.30176]
# [456.2505]
# [834.48926]
# [1052.6074]
# [1446.8857]
# [1534.9028]
# [1129.229]
# [871.6211]
# [616.917]
# [407.917]
# [415.81396]
# [178.79102]
# [-31.355469]
# [56.63867]
# [110.61279]
# [350.93408]
# [282.31055]

# %%
# calcute MAPE Error on test data

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

MAPE=mean_absolute_percentage_error(y_test, y_test_hat)
MAPE
# Out:
# 11.684035471470951

# %%
# plot the y_test and y_test_hat (prediction on test data)

plt.figure(figsize=(16, 8))
plt.title('Univariate Stacked LSTM - Load Prediction from 2020-07-27 - 2020-08-02 with MAPE='+ str(MAPE))
plt.plot(y_test, 'o--', alpha=1)
plt.plot(y_test_hat, 'o--', alpha=0.9)
plt.xlabel('Date', fontsize=18)
plt.ylabel('Load', fontsize=18)
plt.legend(['true volume', 'predicted volume'], loc='upper right')

plt.show()

# %% [raw]
# # serialize model to JSON
# model_json = model.to_json()
# with open("modelstack500n6450.json", "w") as json_file:
#     json_file.write(model_json)
# # serialize weights to HDF5
# model.save_weights("modelstack500n6450.h5")
# print("Saved model to disk")

# %% [markdown]
# # Visuliza Model + RMSE + Weights

# %%
from tensorflow.keras.utils.vis_utils import plot_model
# pip install pydot
# conda install python-graphviz

plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

def measure_rmse(actual, predicted):
    return sqrt(mean_squared_error(actual, predicted))

RMSE=measure_rmse(y_test, y_test_hat)
RMSE

# %%
for layer in model.layers:
    weights = layer.get_weights() 
    
weights
